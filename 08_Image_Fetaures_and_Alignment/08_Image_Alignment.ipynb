# %% [markdown]
# # Image Alignment
# **Satya Mallick, LearnOpenCV.com**

# %% [markdown]
# ## Align an image to a template.
# ![alt text](image-alignment-using-opencv.jpg "Image Alignment")

# %% [markdown]
# ## Theory
#
# 1. A **Homography** transforms a square to arbitrary quad.
#
# ![alt text](motion-models.jpg "Motion Models")

# %% [markdown]
# ## Theory
# 2. Images of two planes are related by a **Homography**
# 3. We need **4 corresponding points** to estimate Homography
#
#
# !["Homography Example"](homography-example.jpg)|

# %%
# Imports
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Read Tempalate and Scanned Image

# %%
# Read reference image
refFilename = "form.jpg"
print("Reading reference image : ", refFilename)
im1 = cv2.imread(refFilename, cv2.IMREAD_COLOR)
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)

# Read image to be aligned
imFilename = "scanned-form.jpg"
print("Reading image to align : ", imFilename)
im2 = cv2.imread(imFilename, cv2.IMREAD_COLOR)
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)
# Out:
# Reading reference image :  form.jpg
# Reading image to align :  scanned-form.jpg

# %%
# Display Images

plt.figure(figsize=[20,10]); 
plt.subplot(121); plt.axis('off'); plt.imshow(im1); plt.title("Original Form")
plt.subplot(122); plt.axis('off'); plt.imshow(im2); plt.title("Scanned Form")
# Out:
# Text(0.5, 1.0, 'Scanned Form')

# %% [markdown]
# ## Step 2: Find keypoints in both Images
#
# Piense en los puntos clave como puntos de esquina que son estables bajo transformaciones de imagen

# %%
# Convert images to grayscale
im1_gray = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
im2_gray = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
  

# Detect ORB features (bordes, esquinas, texturas, etc) and compute descriptors.
MAX_NUM_FEATURES = 500  # El número máximo de features a conservar.

orb = cv2.ORB_create(MAX_NUM_FEATURES)
# Listado de puntos clave y descriptores
 # La idea es que si estamos buscando el mismo keypoint en ambas imagenes podemos intentar usar los descriptores
 # para que coincidan, los descriptores de orb son cadenas binarias
keypoints1, descriptors1 = orb.detectAndCompute(im1_gray, None)
keypoints2, descriptors2 = orb.detectAndCompute(im2_gray, None)

# Display 
im1_display = cv2.drawKeypoints(im1, keypoints1, outImage=np.array([]), color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
im2_display = cv2.drawKeypoints(im2, keypoints2, outImage=np.array([]), color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
plt.figure(figsize=[20,10])
plt.subplot(121); plt.axis('off'); plt.imshow(im1_display); plt.title("Original Form");
plt.subplot(122); plt.axis('off'); plt.imshow(im2_display); plt.title("Scanned Form");

# %% [markdown]
# ## Step 3 : Match keypoints in the two image

# %%
# Match features.
# Definiendo el tipo de algoritmo de coincidencia y la metrica para calcular la distancia entre descriptores: cv2.DESCRIPTOR_MATCHER_BRUTEFORCE_HAMMING
matcher = cv2.DescriptorMatcher_create(cv2.DESCRIPTOR_MATCHER_BRUTEFORCE_HAMMING)
# Proporciona una lista de las mejores coincidencias
matches = matcher.match(descriptors1, descriptors2, None)
  
# Sort matches by score
# Ordenamos la lista en funcion de la distancia entre los descriptores
matches.sort(key=lambda x: x.distance, reverse=False)

# Remove not so good matches
numGoodMatches = int(len(matches) * 0.1)
matches = matches[:numGoodMatches]

# %%
# Draw top matches
im_matches = cv2.drawMatches(im1, keypoints1, im2, keypoints2, matches, None)

plt.figure(figsize=[40,10])
plt.imshow(im_matches); plt.axis('off'); plt.title("Original Form");

# %% [markdown]
# ## Step 4:  Find Homography

# %%
# Extract location of good matches
points1 = np.zeros((len(matches), 2), dtype=np.float32)
points2 = np.zeros((len(matches), 2), dtype=np.float32)

for i, match in enumerate(matches):
  points1[i, :] = keypoints1[match.queryIdx].pt
  points2[i, :] = keypoints2[match.trainIdx].pt
  
# Find homography
# Algoritmo para calcular la homografia : cv2.RANSAC
h, mask = cv2.findHomography(points2, points1, cv2.RANSAC)

# %% [markdown]
# ## Step 5: Warp image

# %%
# Use homography to warp image
height, width, channels = im1.shape
im2_reg = cv2.warpPerspective(im2, h, (width, height))
# Display results 
plt.figure(figsize=[20,10]); 
plt.subplot(121); plt.imshow(im1); plt.axis('off'); plt.title("Original Form");
plt.subplot(122); plt.imshow(im2_reg); plt.axis('off'); plt.title("Scanned Form");
